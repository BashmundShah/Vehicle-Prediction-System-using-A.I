# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import KFold,GridSearchCV,cross_val_score,cross_val_predict,train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cars/preprocessed.csv")
df = df.sample(frac=1).reset_index(drop=True)
print(df.shape)
kfold = KFold(n_splits=10, random_state=7,shuffle=True)
# Out:
# (2676, 133)

# %%
lr=LinearRegression()
x=df.drop(['price','id','Unnamed: 0'],axis=1)
y=df.price
xTrain,xTest,yTrain,yTest=train_test_split(x,y)
lr.fit(xTrain,yTrain)
print("Sample Accuracy",lr.score(xTest,yTest))
results = cross_val_score(lr, x, y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
predict=cross_val_predict(lr,x,y,cv=kfold)
fig,ax=plt.subplots()
ax.scatter(y,predict,edgecolors=(0,0,0))
ax.plot([y.min(),y.max()],[y.min(),y.max()],'k--',lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
# Sample Accuracy 0.8730728836256798
# Accuracy: -72801702.48% (168268024.31%)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(loss='ls',max_depth=5)
gbr.fit(xTrain,yTrain)
print("Sample Accuracy:",gbr.score(xTest,yTest))
results = cross_val_score(gbr, x, y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
predict=cross_val_predict(gbr,x,y,cv=kfold)
fig,ax=plt.subplots()
ax.scatter(y,predict,edgecolors=(0,0,0))
ax.plot([y.min(),y.max()],[y.min(),y.max()],'k--',lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
# Sample Accuracy: 0.9701247380355333
# Accuracy: 96.70% (1.29%)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(max_depth=5,n_estimators=100)
rfr.fit(xTrain,yTrain)
print("Sample Accuracy:",rfr.score(xTest,yTest))
results = cross_val_score(rfr, x, y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
predict=cross_val_predict(rfr,x,y,cv=kfold)
fig,ax=plt.subplots()
ax.scatter(y,predict,edgecolors=(0,0,0))
ax.plot([y.min(),y.max()],[y.min(),y.max()],'k--',lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
# Sample Accuracy: 0.9626482380303151
# Accuracy: 95.63% (1.16%)

# %% [markdown]
# Saving the trained models

# %%
import pickle
filename = 'Models/linear_model.sav'
pickle.dump(lr, open(filename, 'wb'))
filename = 'Models/gradientbooster_model.sav'
pickle.dump(gbr, open(filename, 'wb'))
filename = 'Models/randomforest_model.sav'
pickle.dump(rfr, open(filename, 'wb'))

# %%
xTrain.dtypes
# Out:
# year                    int64
# mileage                 int64
# enginetype              int64
# enginecapacity          int64
# make_mazda              int64
# make_mitsubishi         int64
# make_suzuki             int64
# make_toyota             int64
# model_corolla           int64
# model_mehran            int64
# model_pajero            int64
# model_scrum             int64
# color_beige             int64
# color_black             int64
# color_blue              int64
# color_bronze            int64
# color_bronze mica       int64
# color_brown             int64
# color_burgundy          int64
# color_c in pix          int64
# color_f micah           int64
# color_gery              int64
# color_gold              int64
# color_graphite green    int64
# color_graphite grey     int64
# color_gray matalic      int64
# color_green             int64
# color_green van         int64
# color_greenish grey     int64
# color_grey              int64
#                         ...
# city_khushab            int64
# city_lahore             int64
# city_lodhran            int64
# city_mandi bahauddin    int64
# city_mansahra           int64
# city_mardan             int64
# city_mian wali          int64
# city_mirpur a.k.        int64
# city_mirpur khas        int64
# city_multan             int64
# city_muzaffar gargh     int64
# city_muzaffarabad       int64
# city_noshero feroze     int64
# city_nowshera           int64
# city_okara              int64
# city_peshawar           int64
# city_quetta             int64
# city_rahim yar khan     int64
# city_rawalpindi         int64
# city_sahiwal            int64
# city_sargodha           int64
# city_sawabi             int64
# city_shiekhopura        int64
# city_sialkot            int64
# city_sukkur             int64
# city_swat               int64
# city_toba tek singh     int64
# city_un-registered      int64
# city_vehari             int64
# city_wah cantt          int64
# Length: 130, dtype: object
